# %%
firstname = 'Viena'
print(firstname)
# Out:
# Viena

# %%
#Datatypes
x = 2
y = 3.14
z = 2 + 3j

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
print(type(y))
# Out:
# <class 'float'>

# %%
print(type(z))
# Out:
# <class 'complex'>

# %% [markdown]
# ## Sequence

# %%
list_ = [1,2,3,4,5]
tuple_ = (1,2,3,4,5)
range_ = range(1,5)

# %%
print(type(list_))
# Out:
# <class 'list'>

# %%
print(type(tuple_))
# Out:
# <class 'tuple'>

# %%
print(type(range_))
# Out:
# <class 'range'>

# %%
list_ = [1,2,3,4,5]
print(type(list_))
# Out:
# <class 'list'>

# %% [markdown]
# ## Mapping

# %%
parocyber = {'name': 'Viena',"age": 23,'sport':'basketball','food':'pilau'}

# %%
parocyber['name']
# Out:
# 'Viena'

# %%
Kenya  = {'coast':'Mombasa','Western':'Bungoma','Eastern':'Moyale', 'Central':'Kiambu'}
print(Kenya)
# Out:
# {'coast': 'Mombasa', 'Western': 'Bungoma', 'Eastern': 'Moyale', 'Central': 'Kiambu'}

# %%
Kenya['Western']
# Out:
# 'Bungoma'
